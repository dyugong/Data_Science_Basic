# %% [markdown]
# <a href="https://colab.research.google.com/github/dyugong/Data_Science_Basic/blob/main/united_summer2015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
united = Table.read_table('united_summer2015.csv')
united
# Out:
# Date   | Flight Number | Destination | Delay
# 6/1/15 | 73            | HNL         | 257
# 6/1/15 | 217           | EWR         | 28
# 6/1/15 | 237           | STL         | -3
# 6/1/15 | 250           | SAN         | 0
# 6/1/15 | 267           | PHL         | 64
# 6/1/15 | 273           | SEA         | -6
# 6/1/15 | 278           | SEA         | -8
# 6/1/15 | 292           | EWR         | 12
# 6/1/15 | 300           | HNL         | 20
# 6/1/15 | 317           | IND         | -10
# ... (13815 rows omitted)

# %%
united.column('Delay').min()
# Out:
# -16

# %%
united.column('Delay').max()
# Out:
# 580

# %%
delay_bins = np.append(np.arange(-20, 301, 10), 600)
united.hist('Delay', bins = delay_bins, unit = 'minute')

# %%
united.where('Delay', are.above(200)).num_rows/united.num_rows
# Out:
# 0.008390596745027125

# %%
delay_bins = np.arange(-20, 201, 10)
united.hist('Delay', bins = delay_bins, unit = 'minute')

# %%
united.where('Delay', are.between(0,10)).num_rows/united.num_rows
# Out:
# 0.2935985533453888

# %%
def empirical_hist_delay(n):
  united.sample(n).hist('Delay', bins = delay_bins, unit = 'minute')

# %%
empirical_hist_delay(10)

# %%
empirical_hist_delay(100)

# %%
empirical_hist_delay(1000)
